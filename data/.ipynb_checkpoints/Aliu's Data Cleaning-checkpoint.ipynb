# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats

# %%
data = pd.read_csv('CandidateSummaryAction1.csv')

# %%
data.head()
# Out:
#       can_id           can_nam can_off can_off_sta  can_off_dis can_par_aff  \
# 0  H2GA12121  ALLEN, RICHARD W       H          GA         12.0         REP
# 1  H6PA02171     EVANS, DWIGHT       H          PA          2.0         DEM
# 2  H6FL04105  RUTHERFORD, JOHN       H          FL          4.0         REP
# 3  H4MT01041     ZINKE, RYAN K       H          MT          0.0         REP
# 4  H8CA09060      LEE, BARBARA       H          CA         13.0         DEM
#
#   can_inc_cha_ope_sea                 can_str1 can_str2       can_cit  ...  \
# 0           INCUMBENT          2237 PICKENS RD      NaN       AUGUSTA  ...
# 1          CHALLENGER              PO BOX 6578      NaN  PHILADELPHIA  ...
# 2                OPEN  3817 VICKERS LAKE DRIVE      NaN  JACKSONVILLE  ...
# 3           INCUMBENT             409 2ND ST W      NaN     WHITEFISH  ...
# 4           INCUMBENT     409 13TH ST, 17TH FL      NaN       OAKLAND  ...
#
#   cas_on_han_beg_of_per  cas_on_han_clo_of_per         net_con  \
# 0           $60,109.57            $175,613.35   $1,074,949.50
# 1                   NaN           $105,687.23   $1,406,719.06
# 2                   NaN            $35,645.09     $650,855.38
# 3           $83,815.78            $399,122.61   $4,938,943.74
# 4           $83,690.60            $181,338.23   $1,197,676.61
#
#       net_ope_exp  deb_owe_by_com deb_owe_to_com cov_sta_dat cov_end_dat  \
# 0    $907,156.21   $1,125,000.00             NaN    1/1/2015  10/19/2016
# 1  $1,298,831.83              NaN            NaN   11/2/2015  10/19/2016
# 2    $656,210.29      $60,000.00             NaN    4/1/2016  10/19/2016
# 3  $5,055,942.15              NaN            NaN    1/1/2015  10/19/2016
# 4    $949,488.98       $4,401.75             NaN    1/1/2015  10/19/2016
#
#   winner     votes
# 0      Y  158708.0
# 1      Y  310770.0
# 2      Y  286018.0
# 3      Y  280476.0
# 4      Y  277390.0
#
# [5 rows x 51 columns]

# %%
data.isnull().sum()
# Out:
# can_id                      0
# can_nam                     0
# can_off                     0
# can_off_sta                 0
# can_off_dis                 2
# can_par_aff                 1
# can_inc_cha_ope_sea         2
# can_str1                   25
# can_str2                 1692
# can_cit                     1
# can_sta                     8
# can_zip                    25
# ind_ite_con               244
# ind_uni_con               276
# ind_con                   198
# par_com_con              1432
# oth_com_con               803
# can_con                  1139
# tot_con                   119
# tra_fro_oth_aut_com      1553
# can_loa                  1174
# oth_loa                  1747
# tot_loa                  1161
# off_to_ope_exp           1051
# off_to_fun               1810
# off_to_leg_acc           1813
# oth_rec                  1280
# tot_rec                    93
# ope_exp                    97
# exe_leg_acc_dis          1808
# fun_dis                  1799
# tra_to_oth_aut_com       1661
# can_loa_rep              1520
# oth_loa_rep              1781
# tot_loa_rep              1508
# ind_ref                   983
# par_com_ref              1790
# oth_com_ref              1452
# tot_con_ref               942
# oth_dis                  1019
# tot_dis                    84
# cas_on_han_beg_of_per    1114
# cas_on_han_clo_of_per     380
# net_con                   171
# net_ope_exp               149
# deb_owe_by_com           1082
# deb_owe_to_com           1791
# cov_sta_dat                 0
# cov_end_dat                 0
# winner                   1343
# votes                    1435
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1814 entries, 0 to 1813
# Data columns (total 51 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   can_id                 1814 non-null   object
#  1   can_nam                1814 non-null   object
#  2   can_off                1814 non-null   object
#  3   can_off_sta            1814 non-null   object
#  4   can_off_dis            1812 non-null   float64
#  5   can_par_aff            1813 non-null   object
#  6   can_inc_cha_ope_sea    1812 non-null   object
#  7   can_str1               1789 non-null   object
#  8   can_str2               122 non-null    object
#  9   can_cit                1813 non-null   object
#  10  can_sta                1806 non-null   object
#  11  can_zip                1789 non-null   float64
#  12  ind_ite_con            1570 non-null   object
#  13  ind_uni_con            1538 non-null   object
#  14  ind_con                1616 non-null   object
#  15  par_com_con            382 non-null    object
#  16  oth_com_con            1011 non-null   object
#  17  can_con                675 non-null    object
#  18  tot_con                1695 non-null   object
#  19  tra_fro_oth_aut_com    261 non-null    object
#  20  can_loa                640 non-null    object
#  21  oth_loa                67 non-null     object
#  22  tot_loa                653 non-null    object
#  23  off_to_ope_exp         763 non-null    object
#  24  off_to_fun             4 non-null      object
#  25  off_to_leg_acc         1 non-null      object
#  26  oth_rec                534 non-null    object
#  27  tot_rec                1721 non-null   object
#  28  ope_exp                1717 non-null   object
#  29  exe_leg_acc_dis        6 non-null      object
#  30  fun_dis                15 non-null     object
#  31  tra_to_oth_aut_com     153 non-null    object
#  32  can_loa_rep            294 non-null    object
#  33  oth_loa_rep            33 non-null     object
#  34  tot_loa_rep            306 non-null    object
#  35  ind_ref                831 non-null    object
#  36  par_com_ref            24 non-null     object
#  37  oth_com_ref            362 non-null    object
#  38  tot_con_ref            872 non-null    object
#  39  oth_dis                795 non-null    object
#  40  tot_dis                1730 non-null   object
#  41  cas_on_han_beg_of_per  700 non-null    object
#  42  cas_on_han_clo_of_per  1434 non-null   object
#  43  net_con                1643 non-null   object
#  44  net_ope_exp            1665 non-null   object
#  45  deb_owe_by_com         732 non-null    object
#  46  deb_owe_to_com         23 non-null     object
#  47  cov_sta_dat            1814 non-null   object
#  48  cov_end_dat            1814 non-null   object
#  49  winner                 471 non-null    object
#  50  votes                  379 non-null    float64
# dtypes: float64(3), object(48)
# memory usage: 722.9+ KB

# %%
summary = pd.DataFrame({'null_values': data.isnull().sum(), 'datatypes': data.dtypes})
summary = summary.reset_index()

# %%
summary
# Out:
#                     index  null_values datatypes
# 0                  can_id            0    object
# 1                 can_nam            0    object
# 2                 can_off            0    object
# 3             can_off_sta            0    object
# 4             can_off_dis            2   float64
# 5             can_par_aff            1    object
# 6     can_inc_cha_ope_sea            2    object
# 7                can_str1           25    object
# 8                can_str2         1692    object
# 9                 can_cit            1    object
# 10                can_sta            8    object
# 11                can_zip           25   float64
# 12            ind_ite_con          244    object
# 13            ind_uni_con          276    object
# 14                ind_con          198    object
# 15            par_com_con         1432    object
# 16            oth_com_con          803    object
# 17                can_con         1139    object
# 18                tot_con          119    object
# 19    tra_fro_oth_aut_com         1553    object
# 20                can_loa         1174    object
# 21                oth_loa         1747    object
# 22                tot_loa         1161    object
# 23         off_to_ope_exp         1051    object
# 24             off_to_fun         1810    object
# 25         off_to_leg_acc         1813    object
# 26                oth_rec         1280    object
# 27                tot_rec           93    object
# 28                ope_exp           97    object
# 29        exe_leg_acc_dis         1808    object
# 30                fun_dis         1799    object
# 31     tra_to_oth_aut_com         1661    object
# 32            can_loa_rep         1520    object
# 33            oth_loa_rep         1781    object
# 34            tot_loa_rep         1508    object
# 35                ind_ref          983    object
# 36            par_com_ref         1790    object
# 37            oth_com_ref         1452    object
# 38            tot_con_ref          942    object
# 39                oth_dis         1019    object
# 40                tot_dis           84    object
# 41  cas_on_han_beg_of_per         1114    object
# 42  cas_on_han_clo_of_per          380    object
# 43                net_con          171    object
# 44            net_ope_exp          149    object
# 45         deb_owe_by_com         1082    object
# 46         deb_owe_to_com         1791    object
# 47            cov_sta_dat            0    object
# 48            cov_end_dat            0    object
# 49                 winner         1343    object
# 50                  votes         1435   float64

# %%
data_info = pd.read_html('https://web.archive.org/web/20170118212350/http://www.fec.gov/finance/disclosure/metadata/metadataforcandidatesummary.shtml')

# %%
data_dic = data_info[2]
data_dic.columns = data_dic.iloc[0,:]

# %%
data_info[2]
# Out:
# 0                     Tag                                 Field Name  \
# 0                     Tag                                 Field Name
# 1                 lin_ima  Link to list of reports for the committee
# 2                  can_id                               Candidate Id
# 3                 can_nam                             Candidate Name
# 4                 can_off                           Candidate Office
# 5             can_off_sta                     Candidate Office State
# 6             can_off_dis                  Candidate Office District
# 7             can_par_aff                Candidate Party Affiliation
# 8     can_inc_cha_ope_sea   Candidate Incumbent Challenger Open Seat
# 9                can_str1                         Candidate Street 1
# 10               can_str2                         Candidate Street 2
# 11                can_cit                             Candidate City
# 12                can_sta                            Candidate State
# 13                can_zip                              Candidate Zip
# 14            ind_ite_con           Individual Itemized Contribution
# 15            ind_uni_con         Individual Unitemized Contribution
# 16                ind_con                    Individual Contribution
# 17            par_com_con               Party Committee Contribution
# 18            oth_com_con               Other Committee Contribution
# 19                can_con                     Candidate Contribution
# 20                tot_con                         Total Contribution
# 21    tra_fro_oth_aut_com   Transfer from other Authorized Committee
# 22                can_loa                             Candidate Loan
# 23                oth_loa                                 Other Loan
# 24                tot_loa                                 Total Loan
# 25         off_to_ope_exp           Offsets to Operating Expenditure
# 26             off_to_fun                     Offsets to Fundraising
# 27         off_to_leg_acc                Offsets to Legal Accounting
# 28                oth_rec                             Other Receipts
# 29                tot_rec                             Total Receipts
# 30                ope_exp                      Operating Expenditure
# 31        exe_leg_acc_dis       Exempt Legal Accounting Disbursement
# 32                fun_dis                   Fundraising Disbursement
# 33     tra_to_oth_aut_com     Transfer to Other Authorized Committee
# 34            can_loa_rep                   Candidate Loan Repayment
# 35            oth_loa_rep                       Other Loan Repayment
# 36            tot_loa_rep                       Total Loan Repayment
# 37                ind_ref                          Individual Refund
# 38            par_com_ref                     Party Committee Refund
# 39            oth_com_ref                     Other Committee Refund
# 40            tot_con_ref                  Total Contribution Refund
# 41                oth_dis                         Other Disbursement
# 42                tot_dis                         Total Disbursement
# 43  cas_on_han_beg_of_per           Cash on Hand Beginning of Period
# 44  cas_on_han_clo_of_per               Cash on Hand Close of Period
# 45                net_con                           Net Contribution
# 46            net_ope_exp                  Net Operating Expenditure
# 47         deb_owe_by_com                     Debt Owed by Committee
# 48         deb_owe_to_com                     Debt Owed to Committee
# 49            cov_sta_dat                        Coverage Start Date
# 50            cov_end_dat                          Coverage End Date
#
# 0   Data Type                                        Description  \
# 0   Data Type                                        Description
# 1         URI  List of all disclosure filings for this committee
# 2   Character                                                NaN
# 3   Character                                  Name of candidate
# 4        Text                                office abbreviation
# 5   Character                      Postal abbreviation for state
# 6      Number               District number for House candidates
# 7   Character                                 Party abbreviation
# 8   Character     Incumbent or challenger or open seat indicator
# 9        Text                                     Street address
# 10       Text                                                NaN
# 11       Text                            City of mailing address
# 12       Text                           State of mailing address
# 13     Number                        Zip code of mailing address
# 14   Currency     Sum of itemized contributions from individuals
# 15   Currency   Sum of unitemized contributions from individuals
# 16   Currency               Total contributions from individuals
# 17   Currency                Contributions from party committees
# 18   Currency                Contributions from other committees
# 19   Currency      Contributions from the candidate him(her)self
# 20   Currency                                Total contributions
# 21   Currency                                                NaN
# 22   Currency                  Loans received from the candidate
# 23   Currency                                        Other loans
# 24   Currency                                                NaN
# 25   Currency                                                NaN
# 26   Currency                                                NaN
# 27   Currency                                                NaN
# 28   Currency                                                NaN
# 29   Currency                                                NaN
# 30   Currency                                                NaN
# 31   Currency                                                NaN
# 32   Currency                                                NaN
# 33   Currency                                                NaN
# 34   Currency                   Loan repayments to the candidate
# 35   Currency                 Loan repayments to banks or others
# 36   Currency                                                NaN
# 37   Currency           Contribution refunds made to individuals
# 38   Currency               Contribution refunds made to parties
# 39   Currency      Contribution refunds made to other committees
# 40   Currency                                                NaN
# 41   Currency                                                NaN
# 42   Currency                                                NaN
# 43   Currency                                                NaN
# 44   Currency                                                NaN
# 45   Currency                                                NaN
# 46   Currency                                                NaN
# 47   Currency                                                NaN
# 48   Currency                                                NaN
# 49       Date                                         MM/DD/YYYY
# 50       Date                                         MM/DD/YYYY
#
# 0               Range                                        Explanation
# 0               Range                                        Explanation
# 1                 NaN  Link to list of filings made directly by the c...
# 2        9 characters  First character indicates office sought - H=Ho...
# 3   Max 90 characters                                                NaN
# 4         1 character                     P=President; S=Senate; H=House
# 5        2 characters                                                NaN
# 6            2 digits                                                NaN
# 7        3 characters  Dem=Democrat  Rep=Republican  full list of Par...
# 8       10 characters  I=incumbent; C=challenger; O=open seat (where ...
# 9                 NaN  Provided by the candidate on a statement of ca...
# 10                NaN  Generally suite number or other secondary address
# 11                NaN  Note: mailing addresses are not necessarily wi...
# 12                NaN                                                NaN
# 13           5 digits                                                NaN
# 14                NaN  Contributions must be itemized (i.e. listing s...
# 15                NaN  Total given to the campaign where specific inf...
# 16                NaN  Sum of the previous two fields (i.e. ind_ite_c...
# 17                NaN        These must be itemized regardless of amount
# 18                NaN  Mostly contributions from PACs, also includes ...
# 19                NaN                                                NaN
# 20                NaN  Sum of the previous 4 fields (i.e. ind_con, pa...
# 21                NaN  Candidates may have more than one committee wo...
# 22                NaN                                                NaN
# 23                NaN  Often from banks, but must be made in the norm...
# 24                NaN  Sum of the previous 2 fields (i.e. can_loa and...
# 25                NaN        e.g. refund of deposit for phone bank, etc.
# 26                NaN  Applies only for Presidential candidates recei...
# 27                NaN  Applies only for Presidential candidates recei...
# 28                NaN  e.g. interest on bank deposits, capital gains,...
# 29                NaN                      Sum of all receipt categories
# 30                NaN  Total of normal operating expenditures. These ...
# 31                NaN  Applies only for Presidential candidates recei...
# 32                NaN  Applies only for Presidential candidates recei...
# 33                NaN  Candidates may have more than one committee wo...
# 34                NaN                                                NaN
# 35                NaN                                                NaN
# 36                NaN  Sum of the previous 2 fields (i.e. can_loa_rep...
# 37                NaN                                                NaN
# 38                NaN                                                NaN
# 39                NaN                    Mainly PACs or other candidates
# 40                NaN  Sum of the previous 3 fields (i.e. ind_ref, pa...
# 41                NaN  e.g. donations to charity, contributions to st...
# 42                NaN                 Sum of all disbursement categories
# 43                NaN  Cash balance for the campaign at the start of ...
# 44                NaN      Ending cash balance on the most recent filing
# 45                NaN  Sum of all contributions minus any contributio...
# 46                NaN  Sum of all operating expenditures minus any of...
# 47                NaN                                                NaN
# 48                NaN                                                NaN
# 49                NaN  Beginning date for the first report during the...
# 50                NaN              Ending date of the most recent report

# %%
data_dic.columns
# Out:
# Index(['Tag', 'Field Name', 'Data Type', 'Description', 'Range',
#        'Explanation'],
#       dtype='object', name=0)

# %%
data_dic = data_dic.drop([0, 1], axis = 0)
data_dic = data_dic.reset_index(drop=True)
data_dic.head()
# Out:
# 0          Tag                 Field Name  Data Type  \
# 0       can_id               Candidate Id  Character
# 1      can_nam             Candidate Name  Character
# 2      can_off           Candidate Office       Text
# 3  can_off_sta     Candidate Office State  Character
# 4  can_off_dis  Candidate Office District     Number
#
# 0                           Description              Range  \
# 0                                   NaN       9 characters
# 1                     Name of candidate  Max 90 characters
# 2                   office abbreviation        1 character
# 3         Postal abbreviation for state       2 characters
# 4  District number for House candidates           2 digits
#
# 0                                        Explanation
# 0  First character indicates office sought - H=Ho...
# 1                                                NaN
# 2                     P=President; S=Senate; H=House
# 3                                                NaN
# 4                                                NaN

# %%
data_dic.to_csv('data_dic.csv')

# %%
frame = [['winner', 0, 'object',0,0,0], ['votes', 0,'float',0,0,0]]

# %%
frame
# Out:
# [['winner', 0, 'object', 0, 0, 0], ['votes', 0, 'float', 0, 0, 0]]

# %%
winners_votes = pd.DataFrame(frame, columns=data_dic.columns, index = [49, 50])

# %%
winners_votes
# Out:
# 0      Tag  Field Name Data Type  Description  Range  Explanation
# 49  winner           0    object            0      0            0
# 50   votes           0     float            0      0            0

# %%
data_dic = pd.concat([data_dic, winners_votes], axis = 0)
data_dic.head()
# Out:
# 0          Tag                 Field Name  Data Type  \
# 0       can_id               Candidate Id  Character
# 1      can_nam             Candidate Name  Character
# 2      can_off           Candidate Office       Text
# 3  can_off_sta     Candidate Office State  Character
# 4  can_off_dis  Candidate Office District     Number
#
# 0                           Description              Range  \
# 0                                   NaN       9 characters
# 1                     Name of candidate  Max 90 characters
# 2                   office abbreviation        1 character
# 3         Postal abbreviation for state       2 characters
# 4  District number for House candidates           2 digits
#
# 0                                        Explanation
# 0  First character indicates office sought - H=Ho...
# 1                                                NaN
# 2                     P=President; S=Senate; H=House
# 3                                                NaN
# 4                                                NaN

# %%
summary['correct_dtypes'] = data_dic['Data Type']

# %%
curr_col = summary[summary['correct_dtypes']=='Currency']['index'].to_list()

# %%
curr_col
# Out:
# ['ind_ite_con',
#  'ind_uni_con',
#  'ind_con',
#  'par_com_con',
#  'oth_com_con',
#  'can_con',
#  'tot_con',
#  'tra_fro_oth_aut_com',
#  'can_loa',
#  'oth_loa',
#  'tot_loa',
#  'off_to_ope_exp',
#  'off_to_fun',
#  'off_to_leg_acc',
#  'oth_rec',
#  'tot_rec',
#  'ope_exp',
#  'exe_leg_acc_dis',
#  'fun_dis',
#  'tra_to_oth_aut_com',
#  'can_loa_rep',
#  'oth_loa_rep',
#  'tot_loa_rep',
#  'ind_ref',
#  'par_com_ref',
#  'oth_com_ref',
#  'tot_con_ref',
#  'oth_dis',
#  'tot_dis',
#  'cas_on_han_beg_of_per',
#  'cas_on_han_clo_of_per',
#  'net_con',
#  'net_ope_exp',
#  'deb_owe_by_com',
#  'deb_owe_to_com']

# %%
import re

for i in data['ind_ite_con'][]:
   print(type(data['ind_ite_con'][i]))
#col = data['ind_ite_con']
#col
# Out:
#   File "<ipython-input-23-6baa41b23b53>", line 3
#     for i in data['ind_ite_con'][]:
#                                  ^
# SyntaxError: invalid syntax

# %%
data['ind_ite_con'][2]
# Out:
# '$529,030.38 '

# %%
spl = data['ind_ite_con'][2]
if type(spl) == str:
    l = []
    for string in re.split('', data['ind_ite_con'][2]):
        if string.isdigit():
            pass
        else:
            l.append(string)
            print(l)
    l.remove('.')
    split_criterion = '[' + ''.join(list(set(l))) + ']'
    output = ''.join(re.split(split_criterion, data['ind_ite_con'][2])
    
    
# print(float(output))
# Out:
#   File "<ipython-input-26-1bafcdfdfd95>", line 15
#     print(float(output))
#     ^
# SyntaxError: invalid syntax
